# %% [markdown]
# ## Why Seaborn?
#
# - provides a layer of abstraction hence simpler to use
# - better aesthetics
# - more graphs included

# %% [markdown]
# ## 1)Relational Plot
#
# -to see the statistical relation between 2 or more variables.
#
# -Bivariate Analysis
#
# -Plots under this section
#
# 1)lineplot
#
# 2)scatterplot

# %% [markdown]
# ### Import the libraries

# %%
# import the library
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
dia = sns.load_dataset('iris')
dia
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %% [markdown]
# ### Lineplot

# %% [markdown]
# #### How line plot looks in matplotlib

# %%
plt.plot(dia['sepal_length'], dia['petal_width'],marker='*',linestyle="-.")

# %% [markdown]
# #### Plotting same plot using seaborn library

# %%
sns.lineplot(data =dia, x ='sepal_length', y ='petal_width', marker = 'o')
# Out:
# <Axes: xlabel='sepal_length', ylabel='petal_width'>

# %%
sns.lineplot(x = dia['sepal_length'], y = dia['petal_width'], marker = 'o')
# Out:
# <Axes: xlabel='sepal_length', ylabel='petal_width'>

# %%
sns.relplot(kind = 'line',x = dia['sepal_length'], y = dia['petal_width'], marker = 'o')
# Out:
# C:\Users\Dell\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
sns.lineplot(data = dia,x = 'sepal_length', y ='petal_length' , hue = 'species')
# Out:
# <Axes: xlabel='sepal_length', ylabel='petal_length'>

# %%
tips =  sns.load_dataset('tips')
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %% [markdown]
# ### Scatterplot

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Sample dataset
data = {
    'Student': ['Student A', 'Student B', 'Student C', 'Student D'],
    'Test 1 Score': [85, 90, 78, 92],
    'Test 2 Score': [88, 86, 89, 78],
    'Test 3 Score': [92, 80, 85, 88]
}

df = pd.DataFrame(data)
df
# Out:
#      Student  Test 1 Score  Test 2 Score  Test 3 Score
# 0  Student A            85            88            92
# 1  Student B            90            86            80
# 2  Student C            78            89            85
# 3  Student D            92            78            88

# %%
# Create a scatterplot
plt.figure(figsize=(8, 6))
sns.scatterplot(data=df, x='Test 1 Score', y='Test 3 Score',hue='Student', s = 200)

#plt.title('Scatterplot of Test 1 vs. Test 2 Scores')
#plt.xlabel('Test 1 Score')
#plt.ylabel('Test 2 Score')
#plt.legend(loc='best')
#plt.show()
# Out:
# <Axes: xlabel='Test 1 Score', ylabel='Test 3 Score'>

# %%
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
sns.scatterplot(tips, x= "total_bill", y = 'tip', hue = 'day', style = 'time')
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
sns.relplot(tips,kind='scatter',x= "total_bill", y = 'tip', hue = 'time', style = 'day')
# Out:
# C:\Users\Dell\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %% [markdown]
# # 2.Distribution plot
#
# 1. Histplot
# 2. KDE plot

# %% [markdown]
# ### Histplot

# %%
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
sns.histplot(data=tips, x='total_bill')
# Out:
# <Axes: xlabel='total_bill', ylabel='Count'>

# %%
sns.histplot(data=tips, x='total_bill', bins = 10)
# Out:
# <Axes: xlabel='total_bill', ylabel='Count'>

# %%
sns.displot(data=tips,kind = 'hist', x='total_bill', bins = [0,5,10,15,20,25,30,35,40,50,60],)
plt.grid(axis= 'y', alpha= 0.3, c='gray')
# Out:
# C:\Users\Dell\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %% [markdown]
# ### KDE plot

# %%
sns.kdeplot(data=tips, x='total_bill')
# Out:
# <Axes: xlabel='total_bill', ylabel='Density'>

# %%
sns.displot(data=tips,kind = 'kde', x='total_bill')
# Out:
# C:\Users\Dell\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
sns.displot(data=tips,kind = 'kde', x='total_bill',hue='day')
# Out:
# C:\Users\Dell\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %% [markdown]
# ## Categorical Dist plot
#
# 1. Boxplot
# 2. Violine plot

# %% [markdown]
# ## Boxplot

# %%
x =[10,20,30,40,50,60,50,40,120,100,110,10,20,30,]

sns.boxplot(x)
# Out:
# <Axes: >

# %%
x1= pd.DataFrame(x)
x1

x1.describe()
# Out:
#                 0
# count   14.000000
# mean    49.285714
# std     36.260656
# min     10.000000
# 25%     22.500000
# 50%     40.000000
# 75%     57.500000
# max    120.000000

# %%
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
# Box plot
sns.boxplot(data=tips,x='day',y='total_bill')
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
sns.catplot(data=tips,kind ='box',x='day',y='total_bill',hue='sex')
plt.show()
# Out:
# C:\Users\Dell\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
sns.violinplot(data=tips,x='day',y='total_bill')
plt.show()

# %%
sns.catplot(data=tips,kind ='violin',x='day',y='total_bill')
plt.show()
# Out:
# C:\Users\Dell\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %% [markdown]
# ### Heatmap

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Sample dataset
data = {
    'Student': ['Student A', 'Student B', 'Student C', 'Student D'],
    'Test 1 Score': [85, 90, 78, 92],
    'Test 2 Score': [88, 86, 89, 78],
    'Test 3 Score': [92, 80, 85, 88]
}

df = pd.DataFrame(data)
df
# Out:
#      Student  Test 1 Score  Test 2 Score  Test 3 Score
# 0  Student A            85            88            92
# 1  Student B            90            86            80
# 2  Student C            78            89            85
# 3  Student D            92            78            88

# %%
# Set the 'Student' column as the index
df.set_index('Student', inplace=True)
df
# Out:
#            Test 1 Score  Test 2 Score  Test 3 Score
# Student
# Student A            85            88            92
# Student B            90            86            80
# Student C            78            89            85
# Student D            92            78            88

# %%
# Create a custom heatmap
plt.figure(figsize=(8, 6))
sns.heatmap(df, annot = True,cmap = 'magma',fmt = 'd',linewidths=0)  #fmt is formatting of the annotation  d, % , f
#sns.heatmap(df,annot=True,  cmap='YlGnBu', fmt='d', linewidths=0.5)
plt.title('Test Scores Heatmap')
plt.xlabel('Test')
plt.ylabel('Student')
plt.show()

# %%
sns.heatmap(df, annot=True, cmap='viridis', fmt='d', linewidths=0.2)
# Out:
# <Axes: ylabel='Student'>

# %%
df= sns.load_dataset('flights')
df
# Out:
#      year month  passengers
# 0    1949   Jan         112
# 1    1949   Feb         118
# 2    1949   Mar         132
# 3    1949   Apr         129
# 4    1949   May         121
# ..    ...   ...         ...
# 139  1960   Aug         606
# 140  1960   Sep         508
# 141  1960   Oct         461
# 142  1960   Nov         390
# 143  1960   Dec         432
#
# [144 rows x 3 columns]

# %%
df.dtypes
# Out:
# year             int64
# month         category
# passengers       int64
# dtype: object

# %%
flight = df.pivot(index='year', columns='month', values='passengers')
flight
# Out:
# month  Jan  Feb  Mar  Apr  May  Jun  Jul  Aug  Sep  Oct  Nov  Dec
# year
# 1949   112  118  132  129  121  135  148  148  136  119  104  118
# 1950   115  126  141  135  125  149  170  170  158  133  114  140
# 1951   145  150  178  163  172  178  199  199  184  162  146  166
# 1952   171  180  193  181  183  218  230  242  209  191  172  194
# 1953   196  196  236  235  229  243  264  272  237  211  180  201
# 1954   204  188  235  227  234  264  302  293  259  229  203  229
# 1955   242  233  267  269  270  315  364  347  312  274  237  278
# 1956   284  277  317  313  318  374  413  405  355  306  271  306
# 1957   315  301  356  348  355  422  465  467  404  347  305  336
# 1958   340  318  362  348  363  435  491  505  404  359  310  337
# 1959   360  342  406  396  420  472  548  559  463  407  362  405
# 1960   417  391  419  461  472  535  622  606  508  461  390  432

# %%
plt.figure(figsize=(15,18))
sns.heatmap(flight, annot=True, fmt='d', cmap='viridis_r')
# Out:
# <Axes: xlabel='month', ylabel='year'>

# %% [markdown]
# - fmt=".0f": Display values as floating-point numbers with zero decimal places.
# - fmt=".2f": Display values as floating-point numbers with two decimal places.
# - fmt="d": Display values as integers.
# - fmt="s": Display values as strings.

# %% [markdown]
# ## Regression
#
# - Regplot
# - lmplot

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
tips = sns.load_dataset("tips")
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
# regplot => axes level function
sns.regplot(data = tips, x="total_bill", y = "tip")
plt.show()

#Light bluish shade near to line shows error in line so we can also say that upto that range line may be deviated

# %%
sns.lmplot(data = tips, x="total_bill", y = "tip")
plt.show()
# Out:
# C:\Users\Dell\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %% [markdown]
# ### Pairplot

# %%
sns.pairplot(tips)
# Out:
# C:\Users\Dell\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
iris=sns.load_dataset('iris')
iris
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
sns.pairplot(iris)
# Out:
# C:\Users\Dell\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)
